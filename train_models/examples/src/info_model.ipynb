# %%
import pickle

# %%
with open("train_models/examples/models/Facenet512_retinaface_001.pkl", "rb") as f:
    model = pickle.load(f)

# %%
print(type(model))
print(model)
# Out:
# <class 'dict'>
# {'bao': array([ 1.08725953,  0.49560285,  0.14806767,  1.81793034,  1.32085931,
#        -0.6333701 , -0.45728505, -1.1985693 ,  0.08973435, -0.0421401 ,
#         0.43056729,  0.34664354, -1.53843057,  0.15411034, -0.46968117,
#        -1.00076675,  1.52503777,  2.01033926,  0.26261568,  1.82915759,
#        -0.66219455,  1.07540345,  0.96683329, -1.34444726, -1.03132069,
#        -0.38910395,  1.62044001, -0.45133954,  0.61230296,  0.53714013,
#         0.00763457,  0.82211721, -0.2149777 ,  1.42025185,  0.54568899,
#        -2.09025955, -1.73880279, -1.48843932, -0.6504302 ,  1.45948291,
#         0.01122841, -1.08696747, -0.67710054, -0.3532148 , -1.49833453,
#        -0.25752282, -0.61163008,  1.50809944, -2.07070398,  0.82055366,
#         0.15365714, -0.95033896,  1.80366457,  1.0883255 , -0.44499886,
#        -2.13167286, -1.0329082 ,  1.67610395,  0.5695498 ,  1.00840521,
#         0.01924852,  0.22191735,  1.59461999,  1.18003559,  0.16306452,
# ...

# %%
with open("train_models/examples/models/Facenet512_retinaface_004.pkl", "rb") as f:
    model = pickle.load(f)

# %%
print(type(model))
print(model)
# Out:
# <class 'dict'>
# {'version': '004', 'model_name': 'Facenet512', 'detector_backend': 'retinaface', 'created_at': '2026-06-02 17:40:02', 'num_classes': 4, 'total_images': 8, 'failed_images': 0, 'persons': ['bao', 'le_thanh_tung', 'nguyen', 'thinh'], 'images_per_person': {'bao': 2, 'le_thanh_tung': 2, 'nguyen': 2, 'thinh': 2}, 'centroids': {'bao': array([ 0.04673159,  0.02130155,  0.00636411,  0.07813661,  0.05677196,
#        -0.02722293, -0.01965461, -0.0515158 ,  0.00385688, -0.00181123,
#         0.01850625,  0.01489911, -0.06612341,  0.00662383, -0.0201874 ,
#        -0.04301404,  0.06554777,  0.08640656,  0.01128751,  0.07861917,
#        -0.02846184,  0.046222  ,  0.04155554, -0.0577858 , -0.04432728,
#        -0.01672411,  0.06964827, -0.01939906,  0.02631744,  0.02308686,
#         0.00032814,  0.03533548, -0.00923997,  0.06104396,  0.0234543 ,
#        -0.08984162, -0.07473563, -0.06397473, -0.02795619,  0.06273016,
# ...
